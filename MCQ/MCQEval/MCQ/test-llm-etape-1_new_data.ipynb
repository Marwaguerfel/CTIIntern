# %%
# !pip install transformers
# !pip install torch

# %%
import pandas as pd
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch
import os

# %%
# Chemin vers le fichier TSV
file_path = '/kaggle/input/datatesttrain/cti-mcq.tsv'

# Lire le fichier TSV
data = pd.read_csv(file_path, sep='\t')

# %%
# Afficher les premières lignes du dataset
print(data.head())
# Supposons que le dataset contient des colonnes "feature1", "feature2", et "label"
# Nettoyage des données (par exemple, suppression des valeurs manquantes)
data.dropna(inplace=True)
# Out:
#                                           URL  \
# 0  https://attack.mitre.org/techniques/T1548/
# 1  https://attack.mitre.org/techniques/T1548/
# 2  https://attack.mitre.org/techniques/T1548/
# 3  https://attack.mitre.org/techniques/T1548/
# 4  https://attack.mitre.org/techniques/T1548/
#
#                                             Question  \
# 0  Which of the following mitigations involves pr...
# 1  Which data source is recommended for monitorin...
# 2  What does mitigation ID M1028 suggest to preve...
# 3  Which process creation is an indicator of pote...
# 4  In a Linux environment, what is recommended to...
#
#                                     Option A  \
# 0                                      Audit
# 1                                    Command
# 2      Limiting privileges of cloud accounts
# 3           C:\Windows\System32\services.exe
# 4  Monitor Windows Registry Key Modification
#
#                                         Option B  \
# ...

# %%
# Afficher les informations sur le dataset pour vérifier la structure
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2495 entries, 0 to 2499
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   URL       2495 non-null   object
#  1   Question  2495 non-null   object
#  2   Option A  2495 non-null   object
#  3   Option B  2495 non-null   object
#  4   Option C  2495 non-null   object
#  5   Option D  2495 non-null   object
#  6   Prompt    2495 non-null   object
#  7   GT        2495 non-null   object
# dtypes: object(8)
# memory usage: 175.4+ KB
# None

# %%
# Créer un nouveau DataFrame avec les colonnes souhaitées
new_data = data[['Question', 'Option A', 'Option B', 'Option C', 'Option D']]

# Afficher les premières lignes du nouveau DataFrame
print(new_data.head())
