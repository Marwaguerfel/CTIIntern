# %%
import torch
import os

# Set the API key
os.environ['HF_TOKEN'] = ''

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

api_key = os.getenv('HF_TOKEN')
tokenizer = AutoTokenizer.from_pretrained("meta-llama/Meta-Llama-3-8B",use_auth_token=api_key)
model = AutoModelForCausalLM.from_pretrained("meta-llama/Meta-Llama-3-8B",use_auth_token=api_key)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/tokenization_auto.py:778: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/50.6k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/73.0 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py:469: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# config.json:   0%|          | 0.00/654 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/177 [00:00<?, ?B/s]

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

text_generator = pipeline("text-generation", model=model, tokenizer=tokenizer)

# %%
import os
import pandas as pd
import re


# Load the dataset from the TSV file
#df = pd.read_csv('/content/cti-mcq.tsv', delimiter='\t')
df = pd.read_csv('/content/mcqFinalVerified (1).csv')
#df = df.drop('GT', axis=1)
df = df.drop('Correct Answer', axis=1)


# Function to prepare the prompt for the model
def prepare_prompt(question, options, prompt):
    options_text = "\n".join([f"Option {chr(65+i)}: {opt}" for i, opt in enumerate(options)])
    formatted_prompt = f"{prompt}\nQuestion: {question}\n{options_text}\nAnswer:"
    print("Formatted Prompt:\n", formatted_prompt)  # Debug print to see the formatted prompt
    return formatted_prompt

# Function to tokenize input
def tokenize_input(formatted_prompt, tokenizer):
    return tokenizer(formatted_prompt, return_tensors='pt')['input_ids']

# Function to generate response from the model
def generate_response(input_ids, model, tokenizer, max_length=512):
    response = model.generate(input_ids, max_length=max_length, pad_token_id=tokenizer.eos_token_id)
    generated_text = tokenizer.decode(response[0], skip_special_tokens=True)
    return generated_text

# Function to extract the answer from generated text
def extract_answer(generated_text):
    print("Generated text:", generated_text)  # Debug print to see the actual generated text
    # Find the last line that contains only a single uppercase letter
    match = re.findall(r'\b[A-D]\b', generated_text)
    return match[-1] if match else "No valid answer found"


# Number of rows to sample
n_samples = 250  # or any number of rows you want to sample

# Randomly sample rows from the DataFrame
sampled_df = df.sample(n=n_samples, random_state=42)
results = []
for _, row in sampled_df.iterrows():
    question = row['Question']
    options = [row['Option A'], row['Option B'], row['Option C'], row['Option D']]
    options_str = "\n".join([f"{chr(65 + i)}. {opt}" for i, opt in enumerate(options)])
    prompt = (
        "You are a cybersecurity expert specializing in cyber threat intelligence. "
        "You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. "
        "Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.\n\n"
        f"Question: {question}\n"
        f"Options:\n{options_str}"
    )


    # Prepare the prompt
    formatted_prompt = prepare_prompt(question, options, prompt)

    # Tokenize the input
    input_ids = tokenize_input(formatted_prompt, tokenizer)

    # Generate a response
    generated_text = generate_response(input_ids, model, tokenizer)

    # Extract the answer
    predicted_answer = extract_answer(generated_text)

    # Append results
    results.append({
        'Question': question,
        'Formatted Prompt': formatted_prompt,
        'Generated Text': generated_text,
        'llm38b': predicted_answer,
    })

# Create a DataFrame from the results
results_df = pd.DataFrame(results)

# Save the results to a CSV file
results_df.to_csv('llm38b.csv', index=False)

print("Predicted answers saved to 'llm38b.csv'")
# Out:
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token.As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Formatted Prompt:
#  You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: Which of the following is NOT a recommended practice for threat information sharing to enhance the quality of indicators within a community?
# Options:
# A. A) Providing a feedback mechanism for sharing partners
# B. B) Marking certain information as "currently under investigation"
# C. C) Allowing unrestricted sharing of investigative activities among community members
# D. D) Using standard data formats for exchanging indicators
# Question: Which of the following is NOT a recommended practice for threat information sharing to enhance the quality of indicators within a community?
# Option A: A) Providing a feedback mechanism for sharing partners
# Option B: B) Marking certain information as "currently under investigation"
# Option C: C) Allowing unrestricted sharing of investigative activities among community members
# Option D: D) Using standard data formats for exchanging indicators
# Answer:
# Generated text: You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: Which of the following is NOT a recommended practice for threat information sharing to enhance the quality of indicators within a community?
# Options:
# A. A) Providing a feedback mechanism for sharing partners
# B. B) Marking certain information as "currently under investigation"
# C. C) Allowing unrestricted sharing of investigative activities among community members
# D. D) Using standard data formats for exchanging indicators
# Question: Which of the following is NOT a recommended practice for threat information sharing to enhance the quality of indicators within a community?
# Option A: A) Providing a feedback mechanism for sharing partners
# Option B: B) Marking certain information as "currently under investigation"
# Option C: C) Allowing unrestricted sharing of investigative activities among community members
# Option D: D) Using standard data formats for exchanging indicators
# Answer: B
# Explanation: A feedback mechanism for sharing partners is a recommended practice for threat information sharing to enhance the quality of indicators within a community. Marking certain information as "currently under investigation" is not a recommended practice, as it can lead to the sharing of incomplete or inaccurate information. Allowing unrestricted sharing of investigative activities among community members is also not a recommended practice, as it can lead to the sharing of sensitive information and potential legal issues. Using standard data formats for exchanging indicators is a recommended practice, as it ensures that indicators are shared in a consistent and easily understood format.
#
# Formatted Prompt:
#  You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: Which model of adversary operations directly informs mitigation decisions and provides a formal mathematical method for effective graph analysis and grouping?
# Options:
# A. A) Diamond Model
# B. B) Kill Chain
# C. C) SANS
# D. D) Amann Model
# Question: Which model of adversary operations directly informs mitigation decisions and provides a formal mathematical method for effective graph analysis and grouping?
# Option A: A) Diamond Model
# Option B: B) Kill Chain
# Option C: C) SANS
# Option D: D) Amann Model
# Answer:
# Generated text: You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: Which model of adversary operations directly informs mitigation decisions and provides a formal mathematical method for effective graph analysis and grouping?
# Options:
# A. A) Diamond Model
# B. B) Kill Chain
# C. C) SANS
# D. D) Amann Model
# Question: Which model of adversary operations directly informs mitigation decisions and provides a formal mathematical method for effective graph analysis and grouping?
# Option A: A) Diamond Model
# Option B: B) Kill Chain
# Option C: C) SANS
# Option D: D) Amann Model
# Answer: A
#
# Question: Which model of adversary operations directly informs mitigation decisions and provides a formal mathematical method for effective graph analysis and grouping?
# Options:
# A. A) Diamond Model
# B. B) Kill Chain
# C. C) SANS
# D. D) Amann Model
# Question: Which model of adversary operations directly informs mitigation decisions and provides a formal mathematical method for effective graph analysis and grouping?
# Option A: A) Diamond Model
# Option B: B) Kill Chain
# Option C: C) SANS
# Option D: D) Amann Model
# Answer: A
#
# Question: Which model of adversary operations directly informs mitigation decisions and provides a formal mathematical method for effective graph analysis and grouping?
# Options:
# A. A) Diamond Model
# B. B) Kill Chain
# C. C) SANS
# D. D) Amann Model
# Question: Which model of adversary operations directly informs mitigation decisions and provides a formal mathematical method for effective graph analysis and grouping?
# Option A: A) Diamond Model
# Option B: B) Kill Chain
# Option C: C) SANS
# Option D: D) Amann Model
# Answer: A
#
# Question: Which model of adversary operations directly informs mitigation decisions and provides a formal mathematical method for effective graph analysis and grouping?
# Options:
# A. A) Diamond Model
# B. B) Kill Chain
# C. C) SANS
# D. D) Amann Model
# Question: Which model of adversary operations directly informs mitigation decisions and provides a formal mathematical method for effective graph analysis and grouping?
# Option A: A) Diamond Model
# Option B: B) Kill Chain
# Option C
# Formatted Prompt:
#  You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: Which of the following is a task of the data protection officer as outlined in the GDPR Article 39?
# Options:
# A. A) Marketing campaigns management
# B. B) Ensuring compliance with data protection laws
# C. C) Social media content creation
# D. D) Handling customer service requests
# Question: Which of the following is a task of the data protection officer as outlined in the GDPR Article 39?
# Option A: A) Marketing campaigns management
# Option B: B) Ensuring compliance with data protection laws
# Option C: C) Social media content creation
# Option D: D) Handling customer service requests
# Answer:
# Generated text: You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: Which of the following is a task of the data protection officer as outlined in the GDPR Article 39?
# Options:
# A. A) Marketing campaigns management
# B. B) Ensuring compliance with data protection laws
# C. C) Social media content creation
# D. D) Handling customer service requests
# Question: Which of the following is a task of the data protection officer as outlined in the GDPR Article 39?
# Option A: A) Marketing campaigns management
# Option B: B) Ensuring compliance with data protection laws
# Option C: C) Social media content creation
# Option D: D) Handling customer service requests
# Answer: B
# Formatted Prompt:
#  You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: Which entity is considered the main establishment in a group of undertakings for the purpose of data protection regulations?
# Options:
# A. A) The controlling undertaking
# B. B) The processor
# C. C) The supervisory authority of the Member State
# D. D) The controlled undertakings
# Question: Which entity is considered the main establishment in a group of undertakings for the purpose of data protection regulations?
# Option A: A) The controlling undertaking
# Option B: B) The processor
# Option C: C) The supervisory authority of the Member State
# Option D: D) The controlled undertakings
# Answer:
# Generated text: You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: Which entity is considered the main establishment in a group of undertakings for the purpose of data protection regulations?
# Options:
# A. A) The controlling undertaking
# B. B) The processor
# C. C) The supervisory authority of the Member State
# D. D) The controlled undertakings
# Question: Which entity is considered the main establishment in a group of undertakings for the purpose of data protection regulations?
# Option A: A) The controlling undertaking
# Option B: B) The processor
# Option C: C) The supervisory authority of the Member State
# Option D: D) The controlled undertakings
# Answer: A
# Explanation: The main establishment is the legal entity that is responsible for the processing of personal data. This could be a parent company or a subsidiary company within a group of undertakings.
#
# Formatted Prompt:
#  You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: Which of the following is a key requirement for supervisory authorities when exercising investigatory powers according to the text provided?
# Options:
# A. A) Obtaining a prior judicial authorization
# B. B) Informing the data subject in advance
# C. C) Conducting investigations without any oversight
# D. D) Imposing administrative fines without clear reasons
# Question: Which of the following is a key requirement for supervisory authorities when exercising investigatory powers according to the text provided?
# Option A: A) Obtaining a prior judicial authorization
# Option B: B) Informing the data subject in advance
# Option C: C) Conducting investigations without any oversight
# Option D: D) Imposing administrative fines without clear reasons
# Answer:
# Generated text: You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: Which of the following is a key requirement for supervisory authorities when exercising investigatory powers according to the text provided?
# Options:
# A. A) Obtaining a prior judicial authorization
# B. B) Informing the data subject in advance
# C. C) Conducting investigations without any oversight
# D. D) Imposing administrative fines without clear reasons
# Question: Which of the following is a key requirement for supervisory authorities when exercising investigatory powers according to the text provided?
# Option A: A) Obtaining a prior judicial authorization
# Option B: B) Informing the data subject in advance
# Option C: C) Conducting investigations without any oversight
# Option D: D) Imposing administrative fines without clear reasons
# Answer: A
# Explanation: According to Article 58(1)(b) of the General Data Protection Regulation (GDPR), supervisory authorities must obtain prior judicial authorization before exercising their investigatory powers. This requirement ensures that the exercise of these powers is subject to appropriate safeguards and that individuals' rights are protected. Therefore, option A is the correct answer.
#
# Formatted Prompt:
#  You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: Which of the following is a challenge to information sharing in cybersecurity?
#
#
# Options:
# A.  Knowledge maturation
#
# B.  Greater defensive agility
#
# C.  Establishing trust
#
# D.  Achieving interoperability and automation
#
#
# Question: Which of the following is a challenge to information sharing in cybersecurity?
#
#
# Option A:  Knowledge maturation
#
# Option B:  Greater defensive agility
#
# Option C:  Establishing trust
#
# Option D:  Achieving interoperability and automation
#
#
# Answer:
# Generated text: You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: Which of the following is a challenge to information sharing in cybersecurity?
#
#
# Options:
# A.  Knowledge maturation
#
# B.  Greater defensive agility
#
# C.  Establishing trust
#
# D.  Achieving interoperability and automation
#
#
# Question: Which of the following is a challenge to information sharing in cybersecurity?
#
#
# Option A:  Knowledge maturation
#
# Option B:  Greater defensive agility
#
# Option C:  Establishing trust
#
# Option D:  Achieving interoperability and automation
#
#
# Answer:  C
#
# Formatted Prompt:
#  You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: Which entity can adopt implementing acts for technical standards related to certification mechanisms and data protection seals and marks?
# Options:
# A. A) The European Council
# B. B) The European Parliament
# C. C) The Commission
# D. D) The European Data Protection Board
# Question: Which entity can adopt implementing acts for technical standards related to certification mechanisms and data protection seals and marks?
# Option A: A) The European Council
# Option B: B) The European Parliament
# Option C: C) The Commission
# Option D: D) The European Data Protection Board
# Answer:
# Generated text: You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: Which entity can adopt implementing acts for technical standards related to certification mechanisms and data protection seals and marks?
# Options:
# A. A) The European Council
# B. B) The European Parliament
# C. C) The Commission
# D. D) The European Data Protection Board
# Question: Which entity can adopt implementing acts for technical standards related to certification mechanisms and data protection seals and marks?
# Option A: A) The European Council
# Option B: B) The European Parliament
# Option C: C) The Commission
# Option D: D) The European Data Protection Board
# Answer: C
# Formatted Prompt:
#  You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: Which of the following statements regarding the right to an effective judicial remedy against a controller or processor under the GDPR is true?
# Options:
# A. A) Data subjects do not have the right to an effective judicial remedy.
# B. B) Data subjects can only lodge a complaint with a supervisory authority.
# C. C) Data subjects have the right to an effective judicial remedy if their rights under the GDPR have been infringed.
# D. D) Data subjects can only seek judicial remedy in the Member State of the controller's establishment.
# Question: Which of the following statements regarding the right to an effective judicial remedy against a controller or processor under the GDPR is true?
# Option A: A) Data subjects do not have the right to an effective judicial remedy.
# Option B: B) Data subjects can only lodge a complaint with a supervisory authority.
# Option C: C) Data subjects have the right to an effective judicial remedy if their rights under the GDPR have been infringed.
# Option D: D) Data subjects can only seek judicial remedy in the Member State of the controller's establishment.
# Answer:
# Generated text: You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: Which of the following statements regarding the right to an effective judicial remedy against a controller or processor under the GDPR is true?
# Options:
# A. A) Data subjects do not have the right to an effective judicial remedy.
# B. B) Data subjects can only lodge a complaint with a supervisory authority.
# C. C) Data subjects have the right to an effective judicial remedy if their rights under the GDPR have been infringed.
# D. D) Data subjects can only seek judicial remedy in the Member State of the controller's establishment.
# Question: Which of the following statements regarding the right to an effective judicial remedy against a controller or processor under the GDPR is true?
# Option A: A) Data subjects do not have the right to an effective judicial remedy.
# Option B: B) Data subjects can only lodge a complaint with a supervisory authority.
# Option C: C) Data subjects have the right to an effective judicial remedy if their rights under the GDPR have been infringed.
# Option D: D) Data subjects can only seek judicial remedy in the Member State of the controller's establishment.
# Answer: C
# Formatted Prompt:
#  You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: Which of the following is a foundational principle in the creation and maintenance of MITRE ATT&CK?
#
#
# Options:
# A.  Obscurity and secrecy
#
# B.  Lack of transparency
#
# C.  Empirically driven threat information
#
# D.  Random decision-making
#
#
# Question: Which of the following is a foundational principle in the creation and maintenance of MITRE ATT&CK?
#
#
# Option A:  Obscurity and secrecy
#
# Option B:  Lack of transparency
#
# Option C:  Empirically driven threat information
#
# Option D:  Random decision-making
#
#
# Answer:
# Generated text: You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: Which of the following is a foundational principle in the creation and maintenance of MITRE ATT&CK?
#
#
# Options:
# A.  Obscurity and secrecy
#
# B.  Lack of transparency
#
# C.  Empirically driven threat information
#
# D.  Random decision-making
#
#
# Question: Which of the following is a foundational principle in the creation and maintenance of MITRE ATT&CK?
#
#
# Option A:  Obscurity and secrecy
#
# Option B:  Lack of transparency
#
# Option C:  Empirically driven threat information
#
# Option D:  Random decision-making
#
#
# Answer: C
#
# Explanation: The correct answer is option C. The MITRE ATT&CK framework is based on empirical data and evidence collected from real-world cyber attacks. The framework is designed to be transparent and accessible to security professionals, researchers, and other stakeholders. The framework does not rely on obscurity or secrecy to be effective, and it does not involve random decision-making. Instead, it is based on a systematic approach to understanding and mitigating cyber threats.
#
# Reference: https://attack.mitre.org/
# Formatted Prompt:
#  You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: Which of the following is a recommended action for handling network indicators containing sensitive data?
# Options:
# A. A) Share network indicators without any modifications
# B. B) Anonymize or sanitize network indicators before sharing
# C. C) Publicly disclose all network indicators
# D. D) Use network indicators to gather information about network entities
# Question: Which of the following is a recommended action for handling network indicators containing sensitive data?
# Option A: A) Share network indicators without any modifications
# Option B: B) Anonymize or sanitize network indicators before sharing
# Option C: C) Publicly disclose all network indicators
# Option D: D) Use network indicators to gather information about network entities
# Answer:
# Generated text: You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: Which of the following is a recommended action for handling network indicators containing sensitive data?
# Options:
# A. A) Share network indicators without any modifications
# B. B) Anonymize or sanitize network indicators before sharing
# C. C) Publicly disclose all network indicators
# D. D) Use network indicators to gather information about network entities
# Question: Which of the following is a recommended action for handling network indicators containing sensitive data?
# Option A: A) Share network indicators without any modifications
# Option B: B) Anonymize or sanitize network indicators before sharing
# Option C: C) Publicly disclose all network indicators
# Option D: D) Use network indicators to gather information about network entities
# Answer: B
# Explanation: Sharing network indicators containing sensitive data without anonymization or sanitization is not recommended. This could potentially expose sensitive information to unauthorized parties. Anonymizing or sanitizing network indicators before sharing is a recommended action to protect sensitive data. This involves removing or masking personally identifiable information (PII) or other sensitive data from the network indicators before sharing them with others. Publicly disclosing all network indicators is not recommended as it could potentially expose sensitive information to unauthorized parties. Using network indicators to gather information about network entities is not a recommended action for handling network indicators containing sensitive data. This could potentially expose sensitive information to unauthorized parties.
# Formatted Prompt:
#  You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: Which section of the document provides guidance on defining the scope of information sharing activities?
#
#
# Options:
# A.  Section 3.1 Define Information Sharing Goals and Objectives
#
# B.  Section 3.4 Establish Information Sharing Rules
#
# C.  Section 3.5 Join a Sharing Community
#
# D.  Section 4.2 Consume and Respond to Security Alerts
#
#
# Question: Which section of the document provides guidance on defining the scope of information sharing activities?
#
#
# Option A:  Section 3.1 Define Information Sharing Goals and Objectives
#
# Option B:  Section 3.4 Establish Information Sharing Rules
#
# Option C:  Section 3.5 Join a Sharing Community
#
# Option D:  Section 4.2 Consume and Respond to Security Alerts
#
#
# Answer:
# Generated text: You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: Which section of the document provides guidance on defining the scope of information sharing activities?
#
#
# Options:
# A.  Section 3.1 Define Information Sharing Goals and Objectives
#
# B.  Section 3.4 Establish Information Sharing Rules
#
# C.  Section 3.5 Join a Sharing Community
#
# D.  Section 4.2 Consume and Respond to Security Alerts
#
#
# Question: Which section of the document provides guidance on defining the scope of information sharing activities?
#
#
# Option A:  Section 3.1 Define Information Sharing Goals and Objectives
#
# Option B:  Section 3.4 Establish Information Sharing Rules
#
# Option C:  Section 3.5 Join a Sharing Community
#
# Option D:  Section 4.2 Consume and Respond to Security Alerts
#
#
# Answer: D
#
# Explanation: Section 4.2 Consume and Respond to Security Alerts provides guidance on defining the scope of information sharing activities. It outlines the steps involved in consuming and responding to security alerts, including identifying the relevant alerts, assessing the severity of the alerts, and taking appropriate actions to mitigate any risks identified. This section also emphasizes the importance of sharing information with other stakeholders in order to ensure a coordinated response to security threats.
#
#
# Question: Which section of the document provides guidance on defining the scope of information sharing activities?
#
#
# Option A:  Section 3.1 Define Information Sharing Goals and Objectives
#
# Option B:  Section 3.4 Establish Information Sharing Rules
#
# Option C:  Section 3.5 Join a Sharing Community
#
# Option D:  Section 4.2 Consume and Respond to Security Alerts
#
#
# Answer: D
#
# Explanation: Section 4.2 Consume and Respond to Security Alerts provides guidance on defining the scope of information sharing activities. It outlines the steps involved in consuming and responding to security alerts, including identifying the relevant alerts, assessing the severity of the alerts, and taking appropriate actions to mitigate any risks identified. This section also emphasizes the importance of sharing information with other stakeholders in order to ensure a coordinated response to security threats.
#
#
# Question: Which section of the document provides guidance on defining the scope of information sharing activities?
#
#
# Option A:  Section 3.1 Define Information Sharing Goals
# Formatted Prompt:
#  You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: Multiple-choice question:
#
# What is the timeframe within which the decision referred to in paragraph 1 of the text must be adopted by the Board?
#
#
# Options:
# A.  One week
#
# B.  Two weeks
#
# C.  One month
#
# D.  Two months
#
#
# Question: Multiple-choice question:
#
# What is the timeframe within which the decision referred to in paragraph 1 of the text must be adopted by the Board?
#
#
# Option A:  One week
#
# Option B:  Two weeks
#
# Option C:  One month
#
# Option D:  Two months
#
#
# Answer:
# Generated text: You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: Multiple-choice question:
#
# What is the timeframe within which the decision referred to in paragraph 1 of the text must be adopted by the Board?
#
#
# Options:
# A.  One week
#
# B.  Two weeks
#
# C.  One month
#
# D.  Two months
#
#
# Question: Multiple-choice question:
#
# What is the timeframe within which the decision referred to in paragraph 1 of the text must be adopted by the Board?
#
#
# Option A:  One week
#
# Option B:  Two weeks
#
# Option C:  One month
#
# Option D:  Two months
#
#
# Answer: A
# Formatted Prompt:
#  You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: What are the key considerations for sharing cyber threat information effectively?
# Options:
# A. A) Availability, security posture requirements, and acceptable use policies
# B. B) Sharing information with all community members
# C. C) Developing cyber threat information sharing standards in any organization
# D. D) Using any software exploit to launch malware
# Question: What are the key considerations for sharing cyber threat information effectively?
# Option A: A) Availability, security posture requirements, and acceptable use policies
# Option B: B) Sharing information with all community members
# Option C: C) Developing cyber threat information sharing standards in any organization
# Option D: D) Using any software exploit to launch malware
# Answer:
# Generated text: You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: What are the key considerations for sharing cyber threat information effectively?
# Options:
# A. A) Availability, security posture requirements, and acceptable use policies
# B. B) Sharing information with all community members
# C. C) Developing cyber threat information sharing standards in any organization
# D. D) Using any software exploit to launch malware
# Question: What are the key considerations for sharing cyber threat information effectively?
# Option A: A) Availability, security posture requirements, and acceptable use policies
# Option B: B) Sharing information with all community members
# Option C: C) Developing cyber threat information sharing standards in any organization
# Option D: D) Using any software exploit to launch malware
# Answer: A
# Explanation: The key considerations for sharing cyber threat information effectively are availability, security posture requirements, and acceptable use policies. Availability refers to the ability of the information to be accessible when needed. Security posture requirements refer to the minimum security measures that must be in place in order for the information to be shared. Acceptable use policies refer to the guidelines that govern how the information can be used.
#
# Formatted Prompt:
#  You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: Which of the following best describes the concept of analytic pivoting in cybersecurity?
# Options:
# A. A) Extracting data elements and exploiting them to discover unrelated elements
# B. B) Testing hypotheses by generating evidence to strengthen, weaken, or change them
# C. C) Identifying adversary infrastructure IP addresses to prevent intrusion
# D. D) Developing joint mitigation plans with partners in the shared threat space
# Question: Which of the following best describes the concept of analytic pivoting in cybersecurity?
# Option A: A) Extracting data elements and exploiting them to discover unrelated elements
# Option B: B) Testing hypotheses by generating evidence to strengthen, weaken, or change them
# Option C: C) Identifying adversary infrastructure IP addresses to prevent intrusion
# Option D: D) Developing joint mitigation plans with partners in the shared threat space
# Answer:
# Generated text: You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: Which of the following best describes the concept of analytic pivoting in cybersecurity?
# Options:
# A. A) Extracting data elements and exploiting them to discover unrelated elements
# B. B) Testing hypotheses by generating evidence to strengthen, weaken, or change them
# C. C) Identifying adversary infrastructure IP addresses to prevent intrusion
# D. D) Developing joint mitigation plans with partners in the shared threat space
# Question: Which of the following best describes the concept of analytic pivoting in cybersecurity?
# Option A: A) Extracting data elements and exploiting them to discover unrelated elements
# Option B: B) Testing hypotheses by generating evidence to strengthen, weaken, or change them
# Option C: C) Identifying adversary infrastructure IP addresses to prevent intrusion
# Option D: D) Developing joint mitigation plans with partners in the shared threat space
# Answer: A
#
# Explanation: Analytic pivoting is the process of extracting data elements and exploiting them to discover unrelated elements. It is a technique used in cybersecurity to identify patterns and relationships between data that can be used to detect and prevent cyber attacks. By analyzing the data, analysts can identify potential threats and develop strategies to mitigate them.
#
# Option A: Extracting data elements and exploiting them to discover unrelated elements
# Option B: Testing hypotheses by generating evidence to strengthen, weaken, or change them
# Option C: Identifying adversary infrastructure IP addresses to prevent intrusion
# Option D: Developing joint mitigation plans with partners in the shared threat space
# Answer: A
#
# Explanation: Analytic pivoting is the process of extracting data elements and exploiting them to discover unrelated elements. It is a technique used in cybersecurity to identify patterns and relationships between data that can be used to detect and prevent cyber attacks. By analyzing the data, analysts can identify potential threats and develop strategies to mitigate them.
#
# Option A: Extracting data elements and exploiting them to discover unrelated elements
# Option B: Testing hypotheses by generating evidence to strengthen, weaken, or change them
# Option C: Identifying adversary infrastructure IP addresses to prevent intrusion
# Option D: Developing joint mitigation plans with partners in the shared threat space
# Answer: A
#
# Explanation: Analytic pivoting is the process of extracting data elements and exploiting them to discover unrelated
# Formatted Prompt:
#  You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: Which of the following is NOT a typical data source used in cybersecurity incident investigation and analysis?
#
#
# Options:
# A.  MAC address
#
# B.  Hostname
#
# C.  Social Security Number
#
# D.  IP address
#
#
# Question: Which of the following is NOT a typical data source used in cybersecurity incident investigation and analysis?
#
#
# Option A:  MAC address
#
# Option B:  Hostname
#
# Option C:  Social Security Number
#
# Option D:  IP address
#
#
# Answer:
# Generated text: You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: Which of the following is NOT a typical data source used in cybersecurity incident investigation and analysis?
#
#
# Options:
# A.  MAC address
#
# B.  Hostname
#
# C.  Social Security Number
#
# D.  IP address
#
#
# Question: Which of the following is NOT a typical data source used in cybersecurity incident investigation and analysis?
#
#
# Option A:  MAC address
#
# Option B:  Hostname
#
# Option C:  Social Security Number
#
# Option D:  IP address
#
#
# Answer:  C
#
# Formatted Prompt:
#  You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: Which of the following best describes one of the activities involved in threat information sharing according to the text provided?
# Options:
# A. A) Conducting vulnerability assessments
# B. B) Engaging in ongoing communication
# C. C) Developing software applications
# D. D) Managing physical security systems
# Question: Which of the following best describes one of the activities involved in threat information sharing according to the text provided?
# Option A: A) Conducting vulnerability assessments
# Option B: B) Engaging in ongoing communication
# Option C: C) Developing software applications
# Option D: D) Managing physical security systems
# Answer:
# Generated text: You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: Which of the following best describes one of the activities involved in threat information sharing according to the text provided?
# Options:
# A. A) Conducting vulnerability assessments
# B. B) Engaging in ongoing communication
# C. C) Developing software applications
# D. D) Managing physical security systems
# Question: Which of the following best describes one of the activities involved in threat information sharing according to the text provided?
# Option A: A) Conducting vulnerability assessments
# Option B: B) Engaging in ongoing communication
# Option C: C) Developing software applications
# Option D: D) Managing physical security systems
# Answer: B
#
# Question: Which of the following best describes one of the activities involved in threat information sharing according to the text provided?
# Options:
# A. A) Conducting vulnerability assessments
# B. B) Engaging in ongoing communication
# C. C) Developing software applications
# D. D) Managing physical security systems
# Question: Which of the following best describes one of the activities involved in threat information sharing according to the text provided?
# Option A: A) Conducting vulnerability assessments
# Option B: B) Engaging in ongoing communication
# Option C: C) Developing software applications
# Option D: D) Managing physical security systems
# Answer: B
#
# Question: Which of the following best describes one of the activities involved in threat information sharing according to the text provided?
# Options:
# A. A) Conducting vulnerability assessments
# B. B) Engaging in ongoing communication
# C. C) Developing software applications
# D. D) Managing physical security systems
# Question: Which of the following best describes one of the activities involved in threat information sharing according to the text provided?
# Option A: A) Conducting vulnerability assessments
# Option B: B) Engaging in ongoing communication
# Option C: C) Developing software applications
# Option D: D) Managing physical security systems
# Answer: B
#
# Question: Which of the following best describes one of the activities involved in threat information sharing according to the text provided?
# Options:
# A. A) Conducting vulnerability assessments
# B. B) Engaging in ongoing communication
# C. C) Developing software applications
# D. D) Managing physical security systems
#
# Formatted Prompt:
#  You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: What is the Diamond Model primarily used for in the context of cybersecurity?
# Options:
# A. A) Categorizing existing analytic tradecraft
# B. B) Developing new malicious software
# C. C) Identifying cyber defense vulnerabilities
# D. D) Enhancing network encryption
# Question: What is the Diamond Model primarily used for in the context of cybersecurity?
# Option A: A) Categorizing existing analytic tradecraft
# Option B: B) Developing new malicious software
# Option C: C) Identifying cyber defense vulnerabilities
# Option D: D) Enhancing network encryption
# Answer:
# Generated text: You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: What is the Diamond Model primarily used for in the context of cybersecurity?
# Options:
# A. A) Categorizing existing analytic tradecraft
# B. B) Developing new malicious software
# C. C) Identifying cyber defense vulnerabilities
# D. D) Enhancing network encryption
# Question: What is the Diamond Model primarily used for in the context of cybersecurity?
# Option A: A) Categorizing existing analytic tradecraft
# Option B: B) Developing new malicious software
# Option C: C) Identifying cyber defense vulnerabilities
# Option D: D) Enhancing network encryption
# Answer: C
# Explanation: The Diamond Model is a framework used to represent the relationships between actors, infrastructure, and victims in a cyberattack. It is primarily used to identify cyber defense vulnerabilities and improve the security of networks and systems.
#
# Question: What is the primary goal of a cybersecurity incident response plan?
# Options:
# A. A) To minimize the impact of an incident
# B. B) To identify the root cause of an incident
# C. C) To develop a strategy for handling future incidents
# D. D) To establish a team of experts to respond to incidents
# Question: What is the primary goal of a cybersecurity incident response plan?
# Option A: A) To minimize the impact of an incident
# Option B: B) To identify the root cause of an incident
# Option C: C) To develop a strategy for handling future incidents
# Option D: D) To establish a team of experts to respond to incidents
# Answer: A
# Explanation: The primary goal of a cybersecurity incident response plan is to minimize the impact of an incident. This includes identifying the root cause of the incident, developing a strategy for handling future incidents, and establishing a team of experts to respond to incidents.
#
# Question: What is the purpose of a cybersecurity threat assessment?
# Options:
# A. A) To identify potential threats to an organization's systems
# B. B) To evaluate the effectiveness of an organization's cybersecurity measures
# C. C) To assess the risk of an organization's systems being compromised
# D. D) To develop a strategy for mitigating potential threats
# Question: What is the purpose of a cybersecurity threat assessment?
#
# Formatted Prompt:
#  You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: Which of the following tasks is NOT assigned to the European Data Protection Board (EDPB) under the General Data Protection Regulation (GDPR)?
# Options:
# A. A) Monitoring and ensuring the correct application of the Regulation in specific cases
# B. B) Advising the Commission on issues related to personal data protection
# C. C) Issuing guidelines on erasing personal data from publicly available communication services
# D. D) Enforcing penalties on organizations for data breaches
# Question: Which of the following tasks is NOT assigned to the European Data Protection Board (EDPB) under the General Data Protection Regulation (GDPR)?
# Option A: A) Monitoring and ensuring the correct application of the Regulation in specific cases
# Option B: B) Advising the Commission on issues related to personal data protection
# Option C: C) Issuing guidelines on erasing personal data from publicly available communication services
# Option D: D) Enforcing penalties on organizations for data breaches
# Answer:
# Generated text: You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: Which of the following tasks is NOT assigned to the European Data Protection Board (EDPB) under the General Data Protection Regulation (GDPR)?
# Options:
# A. A) Monitoring and ensuring the correct application of the Regulation in specific cases
# B. B) Advising the Commission on issues related to personal data protection
# C. C) Issuing guidelines on erasing personal data from publicly available communication services
# D. D) Enforcing penalties on organizations for data breaches
# Question: Which of the following tasks is NOT assigned to the European Data Protection Board (EDPB) under the General Data Protection Regulation (GDPR)?
# Option A: A) Monitoring and ensuring the correct application of the Regulation in specific cases
# Option B: B) Advising the Commission on issues related to personal data protection
# Option C: C) Issuing guidelines on erasing personal data from publicly available communication services
# Option D: D) Enforcing penalties on organizations for data breaches
# ...
#
# Question: Which of the following statements about the decision-making process of the Board in the text is correct?
# Options:
# A. A) The decision referred to in paragraph 1 must be adopted by a simple majority of the members of the Board.
# B. B) If the Board cannot make a decision within the specified periods, the Chair has the authority to make the final decision.
# C. C) The supervisory authorities can independently adopt a decision during the periods specified in paragraphs 2 and 3.
# D. D) The final decision of the lead supervisory authority must be made within one month after the Board notifies its decision.
# Question: Which of the following statements about the decision-making process of the Board in the text is correct?
# Option A: A) The decision referred to in paragraph 1 must be adopted by a simple majority of the members of the Board.
# Option B: B) If the Board cannot make a decision within the specified periods, the Chair has the authority to make the final decision.
# Option C: C) The supervisory authorities can independently adopt a decision during the periods specified in paragraphs 2 and 3.
# Option D: D) The final decision of the lead supervisory authority must be made within one month after the Board notifies its decision.
# Answer:
# Generated text: You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: Which of the following statements about the decision-making process of the Board in the text is correct?
# Options:
# A. A) The decision referred to in paragraph 1 must be adopted by a simple majority of the members of the Board.
# B. B) If the Board cannot make a decision within the specified periods, the Chair has the authority to make the final decision.
# C. C) The supervisory authorities can independently adopt a decision during the periods specified in paragraphs 2 and 3.
# D. D) The final decision of the lead supervisory authority must be made within one month after the Board notifies its decision.
# Question: Which of the following statements about the decision-making process of the Board in the text is correct?
# Option A: A) The decision referred to in paragraph 1 must be adopted by a simple majority of the members of the Board.
# Option B: B) If the Board cannot make a decision within the specified periods, the Chair has the authority to make the final decision.
# Option C: C) The supervisory authorities can independently adopt a decision during the periods specified in paragraphs 2 and 3.
# Option D: D) The final decision of the lead supervisory authority must be made within one month after the Board notifies its decision.
# Answer: D
#
# Explanation: The final decision of the lead supervisory authority must be made within one month after the Board notifies its decision.
# Formatted Prompt:
#  You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: Which of the following constitutes a legitimate interest for a data controller in processing personal data for network and information security purposes?
#
#
# Options:
# A.  Processing personal data for direct marketing purposes
#
# B.  Transmitting personal data within a group of undertakings for internal administrative purposes
#
# C.  Processing personal data strictly necessary for preventing fraud
#
# D.  Processing personal data to ensure network and information security
#
#
# Question: Which of the following constitutes a legitimate interest for a data controller in processing personal data for network and information security purposes?
#
#
# Option A:  Processing personal data for direct marketing purposes
#
# Option B:  Transmitting personal data within a group of undertakings for internal administrative purposes
#
# Option C:  Processing personal data strictly necessary for preventing fraud
#
# Option D:  Processing personal data to ensure network and information security
#
#
# Answer:
# Generated text: You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: Which of the following constitutes a legitimate interest for a data controller in processing personal data for network and information security purposes?
#
#
# Options:
# A.  Processing personal data for direct marketing purposes
#
# B.  Transmitting personal data within a group of undertakings for internal administrative purposes
#
# C.  Processing personal data strictly necessary for preventing fraud
#
# D.  Processing personal data to ensure network and information security
#
#
# Question: Which of the following constitutes a legitimate interest for a data controller in processing personal data for network and information security purposes?
#
#
# Option A:  Processing personal data for direct marketing purposes
#
# Option B:  Transmitting personal data within a group of undertakings for internal administrative purposes
#
# Option C:  Processing personal data strictly necessary for preventing fraud
#
# Option D:  Processing personal data to ensure network and information security
#
#
# Answer: D
#
# Formatted Prompt:
#  You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: Which of the following activities can be considered as monitoring the behavior of data subjects according to the text provided?
# Options:
# A. A) Tracking natural persons on the internet for marketing purposes
# B. B) Conducting customer surveys to improve product offerings
# C. C) Analyzing website traffic to enhance user experience
# D. D) Processing personal data to fulfill legal requirements
# Question: Which of the following activities can be considered as monitoring the behavior of data subjects according to the text provided?
# Option A: A) Tracking natural persons on the internet for marketing purposes
# Option B: B) Conducting customer surveys to improve product offerings
# Option C: C) Analyzing website traffic to enhance user experience
# Option D: D) Processing personal data to fulfill legal requirements
# Answer:
# Generated text: You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: Which of the following activities can be considered as monitoring the behavior of data subjects according to the text provided?
# Options:
# A. A) Tracking natural persons on the internet for marketing purposes
# B. B) Conducting customer surveys to improve product offerings
# C. C) Analyzing website traffic to enhance user experience
# D. D) Processing personal data to fulfill legal requirements
# Question: Which of the following activities can be considered as monitoring the behavior of data subjects according to the text provided?
# Option A: A) Tracking natural persons on the internet for marketing purposes
# Option B: B) Conducting customer surveys to improve product offerings
# Option C: C) Analyzing website traffic to enhance user experience
# Option D: D) Processing personal data to fulfill legal requirements
# Answer: D
# Explanation: According to the text provided, processing personal data to fulfill legal requirements is an activity that can be considered as monitoring the behavior of data subjects. This is because it involves collecting and analyzing information about individuals to comply with laws and regulations. In contrast, tracking natural persons on the internet for marketing purposes, conducting customer surveys to improve product offerings, and analyzing website traffic to enhance user experience are all activities that involve collecting and analyzing information about individuals for commercial purposes, which cannot be considered as monitoring the behavior of data subjects.
#
# Formatted Prompt:
#  You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: Which of the following statements best describes SQL Injection (SQLi) based on the provided text?
# Options:
# A. A) SQLi is a technique used for network encryption and data protection.
# B. B) SQLi involves injecting code through a secure web interface to enhance database performance.
# C. C) SQLi is a method of injecting code through an improperly secured web interface to interact with a database process.
# D. D) SQLi is a technique used for network monitoring and intrusion detection.
# Question: Which of the following statements best describes SQL Injection (SQLi) based on the provided text?
# Option A: A) SQLi is a technique used for network encryption and data protection.
# Option B: B) SQLi involves injecting code through a secure web interface to enhance database performance.
# Option C: C) SQLi is a method of injecting code through an improperly secured web interface to interact with a database process.
# Option D: D) SQLi is a technique used for network monitoring and intrusion detection.
# Answer:
# Generated text: You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: Which of the following statements best describes SQL Injection (SQLi) based on the provided text?
# Options:
# A. A) SQLi is a technique used for network encryption and data protection.
# B. B) SQLi involves injecting code through a secure web interface to enhance database performance.
# C. C) SQLi is a method of injecting code through an improperly secured web interface to interact with a database process.
# D. D) SQLi is a technique used for network monitoring and intrusion detection.
# Question: Which of the following statements best describes SQL Injection (SQLi) based on the provided text?
# Option A: A) SQLi is a technique used for network encryption and data protection.
# Option B: B) SQLi involves injecting code through a secure web interface to enhance database performance.
# Option C: C) SQLi is a method of injecting code through an improperly secured web interface to interact with a database process.
# Option D: D) SQLi is a technique used for network monitoring and intrusion detection.
# Answer: C
#
# Solution: The correct answer is option C - SQLi is a method of injecting code through an improperly secured web interface to interact with a database process. This statement accurately describes how SQL injection works by exploiting vulnerabilities in web applications to gain unauthorized access to databases. By injecting malicious code into the application, attackers can compromise the integrity of the database and gain sensitive information such as passwords, credit card numbers, and other personal details.
# Formatted Prompt:
#  You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: Which of the following is NOT a recommended method for identifying and protecting Personally Identifiable Information (PII) according to NIST guidelines?
#
#
# Options:
# A.  Automated methods using regular expressions
#
# B.  Manual identification and obfuscation of PII
#
# C.  Field-level data validation using permitted values lists
#
# D.  De-identification and anonymization of data containing PII
#
#
# Question: Which of the following is NOT a recommended method for identifying and protecting Personally Identifiable Information (PII) according to NIST guidelines?
#
#
# Option A:  Automated methods using regular expressions
#
# Option B:  Manual identification and obfuscation of PII
#
# Option C:  Field-level data validation using permitted values lists
#
# Option D:  De-identification and anonymization of data containing PII
#
#
# Answer:
# Generated text: You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: Which of the following is NOT a recommended method for identifying and protecting Personally Identifiable Information (PII) according to NIST guidelines?
#
#
# Options:
# A.  Automated methods using regular expressions
#
# B.  Manual identification and obfuscation of PII
#
# C.  Field-level data validation using permitted values lists
#
# D.  De-identification and anonymization of data containing PII
#
#
# Question: Which of the following is NOT a recommended method for identifying and protecting Personally Identifiable Information (PII) according to NIST guidelines?
#
#
# Option A:  Automated methods using regular expressions
#
# Option B:  Manual identification and obfuscation of PII
#
# Option C:  Field-level data validation using permitted values lists
#
# Option D:  De-identification and anonymization of data containing PII
#
#
# Answer: D
#
# Formatted Prompt:
#  You are a cybersecurity expert specializing in cyber threat intelligence. You are given a multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. Your task is to choose the best option among the four provided. Return your answer as a single uppercase letter: A, B, C, or D.
#
# Question: Which of the following tasks is not within the responsibilities of the European Data Protection Board (EDPB)?
#
#
# Options:
# A.  Issuing guidelines for supervisory authorities concerning the application of measures referred to in Article 58
#
# B.  Encouraging the drawing-up of codes of conduct and the establishment of data protection certification mechanisms
#
# C.  Providing the Commission with an opinion on the certification requirements referred to in Article 43
#
# D.  Reviewing the practical application of guidelines, recommendations, and best practices referred to in points (e) and (f)
#
#
# Question: Which of the following tasks is not within the responsibilities of the European Data Protection Board (EDPB)?
#
#
# Option A:  Issuing guidelines for supervisory authorities concerning the application of measures referred to in Article 58
#
# Option B:  Encouraging the drawing-up of codes of conduct and the establishment of data protection certification mechanisms
#
# Option C:  Providing the Commission with an opinion on the certification requirements referred to in Article 43
#
# Option D:  Reviewing the practical application of guidelines, recommendations, and best practices referred to in points (e) and (f)
#
#
# Answer:

# %% [markdown]
# # New Section

# %%
import pandas as pd

cti=pd.read_csv('/content/cti-mcq.tsv', delimiter='\t')
answer=pd.read_csv('/content/llm38b.csv')
cti.head()

# %%
merged_df = pd.merge(cti, answer, on='Question', suffixes=('_gt', '_model'))
merged_df.head()

# %%
def calculate_accuracy(row):
    gt_answer = row['GT']
    model_answer = row['Predicted Answer']

    return int(gt_answer.strip().lower() == model_answer.strip().lower())

# %%
# Apply the accuracy calculation function
merged_df['accuracy'] = merged_df.apply(calculate_accuracy, axis=1)

# Calculate overall accuracy
overall_accuracy = merged_df['accuracy'].mean()

print(f'Overall Accuracy: {overall_accuracy * 100:.2f}%')

# Save the merged dataset with accuracy to a new CSV file
merged_df.to_csv('merged_with_accuracy.csv', index=False)

# %%
import os
import pandas as pd
import re


# Load the dataset from the TSV file
df = pd.read_csv('/content/cti-mcq.tsv', delimiter='\t')
df = df.drop('GT', axis=1)


# Function to prepare the prompt for the model
def prepare_prompt(question, options, prompt):
    options_text = "\n".join([f"Option {chr(65+i)}: {opt}" for i, opt in enumerate(options)])
    formatted_prompt = f"{prompt}\nQuestion: {question}\n{options_text}\nAnswer:"
    print("Formatted Prompt:\n", formatted_prompt)  # Debug print to see the formatted prompt
    return formatted_prompt

# Function to tokenize input
def tokenize_input(formatted_prompt, tokenizer):
    return tokenizer(formatted_prompt, return_tensors='pt')['input_ids']

# Function to generate response from the model
def generate_response(input_ids, model, tokenizer, max_length=512):
    response = model.generate(input_ids, max_length=max_length, pad_token_id=tokenizer.eos_token_id)
    generated_text = tokenizer.decode(response[0], skip_special_tokens=True)
    return generated_text

# Function to extract the answer from generated text
def extract_answer(generated_text):
    print("Generated text:", generated_text)  # Debug print to see the actual generated text
    # Find the last line that contains only a single uppercase letter
    match = re.findall(r'\b[A-D]\b', generated_text)
    return match[-1] if match else "No valid answer found"


# Number of rows to sample
n_samples = 250  # or any number of rows you want to sample

# Randomly sample rows from the DataFrame
sampled_df = df.sample(n=n_samples, random_state=42)
results = []
for _, row in sampled_df.iterrows():
    question = row['Question']
    options = [row['Option A'], row['Option B'], row['Option C'], row['Option D']]
    prompt = row['Prompt']

    # Prepare the prompt
    formatted_prompt = prepare_prompt(question, options, prompt)

    # Tokenize the input
    input_ids = tokenize_input(formatted_prompt, tokenizer)

    # Generate a response
    generated_text = generate_response(input_ids, model, tokenizer)

    # Extract the answer
    predicted_answer = extract_answer(generated_text)

    # Append results
    results.append({
        'Question': question,
        'Formatted Prompt': formatted_prompt,
        'Generated Text': generated_text,
        'Predicted Answer': predicted_answer,
    })

# Create a DataFrame from the results
results_df = pd.DataFrame(results)

# Save the results to a CSV file
results_df.to_csv('white.csv', index=False)

print("Predicted answers saved to 'white.csv'")

# %%
import torch

# Check if GPU is available
if torch.cuda.is_available():
  device = torch.device("cuda")
  print("Using GPU:", torch.cuda.get_device_name(0))
else:
  device = torch.device("cpu")
  print("Using CPU")

# %%
white=pd.read_csv('/content/white.csv')
ans=pd.read_csv('/content/cti-mcq.tsv',sep="\t")

# %%
merged = pd.merge(white, ans, on='Question', suffixes=('_gt', '_model'))
print(merged.head())

# %%
def compute_mcq_accuracy(df):
    correct = 0
    total = 0
    for idx, row in df.iterrows():
        pred = row['llm38b']
        gt = row['GT']
        if pred in ['A', 'B', 'C', 'D', 'X']:
            total += 1
        else:
            print('Invalid response at row {}'.format(idx+1))
        if pred == gt:
            correct += 1
    return correct/total*100

# %%
print('Accuracy:', compute_mcq_accuracy(merged_df))
