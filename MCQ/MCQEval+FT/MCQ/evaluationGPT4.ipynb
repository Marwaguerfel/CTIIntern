# %%
key =''

# %%
# !pip install openai --upgrade
# Out:
# Collecting openai
#   Downloading openai-1.38.0-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.8.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.7.4)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.20.1)
# Downloading openai-1.38.0-py3-none-any.whl (335 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 335.9/335.9 kB 2.9 MB/s eta 0:00:00
# Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 4.9 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 5.5 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.0 MB/s eta 0:00:00
# Installing collected packages: h11, httpcore, httpx, openai
# Successfully installed h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 openai-1.38.0

# %%
import os
import openai
from openai import OpenAI

# %%
openai.api_key=key
client=OpenAI(api_key=key)

# %%
import pandas as pd

df=pd.read_csv('/content/output_questions (2).tsv', sep='\t')
df.drop(columns=['Correct Answer','Explanation'], inplace=True)
df.head()
# Out:
#                                             Question  \
# 0  Which MITRE ATT&CK technique involves an adver...
# 1  Which MITRE ATT&CK technique involves an adver...
# 2  In the context of MITRE ATT&CK for Enterprise,...
# 3  In the context of MITRE ATT&CK for Enterprise,...
# 4  Which MITRE ATT&CK technique involves an adver...
#
#                                         Option A  \
# 0               Spearphishing Attachment (T1193)
# 1  (A) Exploit Public-Facing Application (T1190)
# 2                      Process Injection (T1055)
# 3  T1548.002 - Abuse Elevation Control Mechanism
# 4  Process Injection (T1055) - Process Injection
#
#                                         Option B  \
# 0                     Social Engineering (T1140)
# 1               (B) Third-party Software (T1072)
# 2                            Data Staged (T1074)
# 3             T1059.001 - Command-Line Interface
# 4  Man-in-the-Middle (T1557) - Man-in-the-Middle
#
#                                             Option C  \
# 0                        Remote Access Tools (T1219)
# 1      (C) Exploitation for Client Execution (T1203)
# 2                        Command and Control (T1009)
# 3                               T1566.001 - Phishing
# 4  Control Device Identification (T818) - Control...
#
#                                             Option D
# 0                   Man-in-the-Middle Attack (T1557)
# 1  (D) Exploitation for Privilege Escalation (T1068)
# 2                           Remote File Copy (T1105)
# 3                         T1078.002 - Valid Accounts
# 4  Manipulate Device Communication (T848) - Manip...

# %%
import os
import openai
from openai import OpenAI

def get_gpt4_response(prompt):
    response = client.chat.completions.create(
        model="gpt-4o",
        messages=[{"role": "user", "content": prompt}],
        max_tokens=150,
        temperature=0.7,
        n=1,
        stop=None
    )
    return response.choices[0].message.content.strip()


def answer_mcq(question, options):
    prompt = (
        "You are a cybersecurity expert specializing in cyber threat intelligence. You are given a "
        "multiple-choice question (MCQ) from a Cyber Threat Intelligence (CTI) knowledge benchmark dataset. "
        "Your task is to choose the best option among the four provided. Return your answer as a "
        "single uppercase letter: A, B, C, or D.\n\n"
        f"Question: {question}\n"
    )
    for i, option in enumerate(options):
        prompt += f"{chr(65 + i)}. {option}\n"
    prompt += "Answer:"

    response = get_gpt4_response(prompt)
    # Extract the answer letter (e.g., "A" from "A. To redirect legitimate traffic to a malicious server")
    answer_letter = response.split('.')[0].strip().upper() if '.' in response else response.strip().upper()
    return answer_letter

def process_csv(file_path):
    df = pd.read_csv(file_path, sep='\t')
    df_sample = df.sample(n=250, random_state=1)
    responses = []

    for _, row in df_sample.iterrows():
        question = row['Question']
        options = [row['Option A'], row['Option B'], row['Option C'], row['Option D']]
        response = answer_mcq(question, options)
        responses.append(response)

    df_sample['GPT-4'] = responses
    return df_sample

# %%
# Example usage
file_path = '/content/output_questions (2).tsv'  # Replace with the path to your CSV file
result_df = process_csv(file_path)
print(result_df[['Question', 'Option A', 'Option B', 'Option C', 'Option D', 'GPT-4']])
# Out:
#                                                Question  \
# 995   Which MITRE ATT&CK technique involves an adver...
# 1104  Which MITRE ATT&CK technique involves an adver...
# 692   Which MITRE ATT&CK technique involves an adver...
# 1452  Which MITRE ATT&CK technique involves an adver...
# 547   Which MITRE ATT&CK technique involves an adver...
# ...                                                 ...
# 65    Which MITRE ATT&CK technique, often used in pr...
# 1596  Which MITRE ATT&CK technique is associated wit...
# 1165  In the context of MITRE ATT&CK for Enterprise,...
# 1147  Which MITRE ATT&CK technique is described as u...
# 1593  Which MITRE ATT&CK technique involves an attac...
#
#                                                Option A  \
# 995                                      SPEAR PHISHING
# 1104                 Discovery: Active Scanning (T1046)
# 692                                      Reconnaissance
# 1452                         Mitigating Control Evasion
# 547                    Reconnaissance - Active Scanning
# ...                                                 ...
# 65                     Spearphishing Attachment (T1193)
# 1596          Exploit Public-Facing Application (T1190)
# 1165                            Rename System Utilities
# 1147  Exfiltration Over Command and Control Channel ...
# 1593  Exfiltration Over Command and Control Channel ...
#
#                                                Option B  \
# 995                                      VALID ACCOUNTS
# 1104         Delivery: Spearphishing Attachment (T1193)
# 692                             Exploitation Collection
# 1452                   VMware vSphere Session Hijacking
# 547                                      Valid Accounts
# ...                                                 ...
# 65                         Theft of Credentials (T1555)
# 1596          Exploitation for Client Execution (T1203)
# 1165                    Exploitation of Remote Services
# 1147                           Remote File Copy (T1105)
# 1593  Phishing for Information (T1598: Phishing for ...
#
#                                                Option C  \
# 995                          APPLICATION LAYER PROTOCOL
# 1104  Execution: Command and Scripting Interpreter (...
# 692                                           Discovery
# 1452                          Subverting Trust Controls
# 547                                   Account Discovery
# ...                                                 ...
# 65                               Valid Accounts (T1078)
# 1596                 Application Layer Protocol (T1071)
# 1165                               Trusted Relationship
# 1147               Spearphishing Attachment (T1566.001)
# 1593             Valid Accounts (T1078: Valid Accounts)
#
#                                    Option D GPT-4
# 995                       MAN-IN-THE-MIDDLE     C
# 1104  Defense Evasion: Masquerading (T1036)     A
# 692                                       B     C
# 1452           Hypervisor Software Backdoor     D
# 547                Network Service Scanning     D
# ...                                     ...   ...
# 65               Credential Dumping (T1003)     C
# 1596               Exploit Zero-Day (T1199)     A
# 1165                             PowerShell     C
# 1147                      Scripting (T1064)     C
# 1593       Data Staged (T1074: Data Staged)     B
#
# [250 rows x 6 columns]

# %%
output_file_path = '/content/GPT4.csv'  # Replace with the desired output path
result_df.to_csv(output_file_path, index=False)

# %%
gpt=pd.read_csv("/content/GPT4.csv")
gpt.head()
# Out:
#                                             Question  \
# 0  Which MITRE ATT&CK technique involves an adver...
# 1  Which MITRE ATT&CK technique involves an adver...
# 2  Which MITRE ATT&CK technique involves an adver...
# 3  Which MITRE ATT&CK technique involves an adver...
# 4  Which MITRE ATT&CK technique involves an adver...
#
#                              Option A  \
# 0                      SPEAR PHISHING
# 1  Discovery: Active Scanning (T1046)
# 2                      Reconnaissance
# 3          Mitigating Control Evasion
# 4    Reconnaissance - Active Scanning
#
#                                      Option B  \
# 0                              VALID ACCOUNTS
# 1  Delivery: Spearphishing Attachment (T1193)
# 2                     Exploitation Collection
# 3            VMware vSphere Session Hijacking
# 4                              Valid Accounts
#
#                                             Option C  \
# 0                         APPLICATION LAYER PROTOCOL
# 1  Execution: Command and Scripting Interpreter (...
# 2                                          Discovery
# 3                          Subverting Trust Controls
# 4                                  Account Discovery
#
#                                 Option D  \
# 0                      MAN-IN-THE-MIDDLE
# 1  Defense Evasion: Masquerading (T1036)
# 2                                      B
# 3           Hypervisor Software Backdoor
# 4               Network Service Scanning
#
#                                       Correct Answer  \
# 0                                                  C
# 1                                                  A
# 2  Adversaries often perform Discovery techniques...
# 3                                                  C
# 4                                  Account Discovery
#
#                                          Explanation GPT-4
# 0  APPLICATION LAYER PROTOCOL (T1071) involves ad...     C
# 1  Adversaries may use Discovery: Active Scanning...     A
# 2                                                NaN     C
# 3  Adversaries can exploit vulnerabilities in vir...     D
# 4  Adversaries may use valid accounts to interact...     D

# %%
def calculate_accuracy(df):
    # Compare model responses to ground truth
    correct = (df['GPT-4'].str.strip().str.upper() == df['Correct Answer'].str.strip().str.upper()).sum()
    total = len(df)
    accuracy = correct / total * 100
    return accuracy

# %%
accuracy = calculate_accuracy(result_df)
print(f"Model Accuracy: {accuracy:.2f}%")
# Out:
# Model Accuracy: 57.60%

# %%
def compute_mcq_accuracy(df):
    correct = 0
    total = 0

    for idx, row in df.iterrows():
        pred = row['GPT-4']
        gt = row['Correct Answer']

        # Check if both pred and gt are not NaN
        if pd.notna(pred) and pd.notna(gt):
            pred = pred.strip().upper()
            gt = gt.strip().upper()

            if pred in ['A', 'B', 'C', 'D']:
                total += 1
                if pred == gt:
                    correct += 1
            else:
                print(f'Invalid response at row {idx+1}: {pred}')
        else:
            print(f'Missing value at row {idx+1}')

    accuracy = (correct / total) * 100 if total > 0 else 0
    return accuracy

accuracy = compute_mcq_accuracy(gpt)
print(f'Accuracy: {accuracy:.2f}%')
# Out:
# Missing value at row 49
# Invalid response at row 59: THE BEST OPTION IS:
#
# B
# Missing value at row 100
# Missing value at row 131
# Missing value at row 132
# Missing value at row 148
# Missing value at row 180
# Accuracy: 59.26%
